# %% [markdown]
# [![Open Chapter 1 In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/GITHUB_ID/AI-Programming-with-GenAI/blob/main/chapter01/practice.ipynb)
#
# > GitHub에서 이 노트북을 보고 있다면 위 버튼을 눌러 Google Colab에서 실행하세요.
# > 업로드 후 `GITHUB_ID`를 교수자 GitHub 아이디로 바꾸면 됩니다.

# %% [markdown]
# # Chapter 1 실습 노트북
# ## 생성형 AI와 AI 활용 코딩
#
# 이 노트북은 Google Colab에서 실행하는 실습 파일입니다.
#
# 실습 목표:
# - Python 코드를 처음 실행해 본다.
# - `print()` 함수를 사용한다.
# - `input()`으로 값을 입력받는다.
# - AI가 만든 코드를 실행하고 수정한다.

# %% [markdown]
# ## 실습 1. Hello, World 출력하기
#
# 아래 코드를 실행해 봅시다.

# %%
print("Hello, World!")

# %% [markdown]
# ## 실습 2. 나만의 문장 출력하기
#
# 아래 문장을 자신의 문장으로 바꾸어 실행해 봅시다.

# %%
print("안녕하세요. 저는 AI 활용 코딩을 배우고 있습니다.")
print("오늘은 Google Colab에서 Python을 처음 실행해 봅니다.")

# %% [markdown]
# ## 실습 3. 이름을 입력받아 인사하기
#
# `input()` 함수는 사용자에게 값을 입력받을 때 사용합니다.

# %%
name = input("이름을 입력하세요: ")
print("안녕하세요,", name, "님!")

# %% [markdown]
# ## 실습 4. AI에게 코드 생성 요청하기
#
# ChatGPT에 다음 Prompt를 입력해 보세요.
#
# ```text
# Python으로 이름과 학과를 입력받아 자기소개를 출력하는 프로그램을 만들어 주세요.
# 프로그래밍을 처음 배우는 대학생도 이해할 수 있도록 주석을 달아 주세요.
# ```
#
# AI가 만든 코드를 아래 코드 셀에 붙여 넣고 실행해 봅니다.

# %%
# 여기에 ChatGPT가 만들어 준 코드를 붙여 넣으세요.
# 실행 후 자신의 정보에 맞게 수정해 보세요.

# %% [markdown]
# ## 실습 5. 오류 수정하기
#
# 아래 코드는 오류가 있습니다. 실행해 보고 오류 메시지를 확인하세요.
#
# 그 다음 ChatGPT에게 오류 메시지를 보여 주고 수정 방법을 물어보세요.

# %%
# 오류가 있는 코드입니다.
# 실행 후 오류를 확인하고 고쳐 보세요.
print("Hello, AI!"

# %% [markdown]
# ## 실습 6. 자기소개 프로그램 만들기
#
# 아래 항목을 출력하는 자기소개 프로그램을 작성하세요.
#
# - 이름
# - 학과
# - 관심 분야
# - 이 수업에서 배우고 싶은 것
# - AI를 활용해 보고 싶은 일

# %%
print("이름: 홍길동")
print("학과: 교양학부")
print("관심 분야: 인공지능")
print("배우고 싶은 것: AI를 활용한 코딩")
print("AI 활용 목표: 간단한 프로그램 만들기")

# %% [markdown]
# ## 정리
#
# 이번 실습에서 배운 내용:
#
# - `print()`로 문장을 출력할 수 있다.
# - `input()`으로 값을 입력받을 수 있다.
# - ChatGPT에게 코드를 요청할 수 있다.
# - 오류 메시지를 보고 수정할 수 있다.
# - AI가 만든 코드는 반드시 실행하고 확인해야 한다.
